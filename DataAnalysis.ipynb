# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("student-lifestyle-and-stress-dataset.csv")
print(df.index)
print("All columns are")
ai=0
for i in df:
    print(ai,i)
    ai+=1
# Out:
# RangeIndex(start=0, stop=25500, step=1)
# All columns are
# 0 Student_Type
# 1 Sleep_Hours
# 2 Study_Hours
# 3 Social_Media_Hours
# 4 Attendance
# 5 Exam_Pressure
# 6 Family_Support
# 7 Month
# 8 Stress_Level

# %%
df.shape
# Out:
# (25500, 9)

# %%
df.head(n=10)
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       school     6.868702     1.711722            3.176942         NaN
# 1       school     8.519088     3.251084            3.880787   93.978465
# 2      college     4.498770     6.306885            2.936172   64.421253
# 3       school     8.591223     2.384922            5.222832   81.868960
# 4      college     5.329293     9.345179            7.815869   85.847982
# 5      college     4.914849          NaN            2.141137   85.144095
# 6      college     6.621709     5.261762            4.879102         NaN
# 7      college     6.357065     2.827955            6.198479   74.180341
# 8      college     8.085219     5.043731            4.660604   89.564367
# 9      college     4.627502     4.743084            5.579822   95.794315
#
#    Exam_Pressure  Family_Support  Month  Stress_Level
# 0            8.0             7.0    2.0             1
# 1            6.0             4.0    3.0             1
# ...

# %%
df.sample(n=10)
# Out:
#       Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 6213       college     4.978520     4.863066            5.261611   99.010576
# 11784       school          NaN     3.142302            3.415697   83.327721
# 3682       college     8.641374     6.630197            5.998087   69.129774
# 17505          NaN     6.916918     5.349685            1.167852   92.121290
# 7091       college     9.898526     3.974926            3.334529   82.121735
# 20065          NaN     2.743091     5.682690            2.369570   59.303438
# 3550       college     7.563887     0.483561            1.717517   85.008469
# 7148       college     8.052819     5.540449            3.433555   74.432494
# 364        college     4.901897     7.277757            0.721139   89.799494
# 18357      college     3.890412     1.491915            3.245887   85.848430
#
#        Exam_Pressure  Family_Support  Month  Stress_Level
# 6213             6.0             8.0    9.0             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25500 entries, 0 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        24248 non-null  object
#  1   Sleep_Hours         24167 non-null  float64
#  2   Study_Hours         24223 non-null  float64
#  3   Social_Media_Hours  24188 non-null  float64
#  4   Attendance          24195 non-null  float64
#  5   Exam_Pressure       24230 non-null  float64
#  6   Family_Support      24209 non-null  float64
#  7   Month               24186 non-null  float64
#  8   Stress_Level        25500 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.8+ MB

# %%
df.isnull()
# Out:
#        Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0             False        False        False               False        True
# 1             False        False        False               False       False
# 2             False        False        False               False       False
# 3             False        False        False               False       False
# 4             False        False        False               False       False
# ...             ...          ...          ...                 ...         ...
# 25495         False        False        False               False       False
# 25496         False        False        False               False       False
# 25497         False        False        False               False       False
# 25498         False        False        False               False       False
# 25499         False        False        False               False       False
#
# ...

# %%
print(df.isnull().sum())
print('null values')
# Out:
# Student_Type          1252
# Sleep_Hours           1333
# Study_Hours           1277
# Social_Media_Hours    1312
# Attendance            1305
# Exam_Pressure         1270
# Family_Support        1291
# Month                 1314
# Stress_Level             0
# dtype: int64
# null values

# %%
df.describe()
# Out:
#         Sleep_Hours   Study_Hours  Social_Media_Hours    Attendance  \
# count  24167.000000  24223.000000        24188.000000  24195.000000
# mean       6.458948      4.696477            3.555614     81.270961
# std        1.504228      2.240148            1.901528     12.052045
# min        2.008586     -1.433434            0.000040     -5.000000
# 25%        5.438360      3.078230            2.152249     73.738894
# 50%        6.542566      4.538138            3.500709     81.942959
# 75%        7.531571      6.135670            4.864312     90.106859
# max        9.997527     22.444460            9.962134    120.000000
#
#        Exam_Pressure  Family_Support         Month  Stress_Level
# count   24230.000000    24209.000000  24186.000000  25500.000000
# mean        5.369748        5.798298      6.500992      0.299882
# std         2.394003        2.232371      3.455308      0.458215
# min         1.000000        1.000000      1.000000      0.000000
# ...

# %%
# Removing null values
df = df.dropna()
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16809 entries, 1 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        16809 non-null  object
#  1   Sleep_Hours         16809 non-null  float64
#  2   Study_Hours         16809 non-null  float64
#  3   Social_Media_Hours  16809 non-null  float64
#  4   Attendance          16809 non-null  float64
#  5   Exam_Pressure       16809 non-null  float64
#  6   Family_Support      16809 non-null  float64
#  7   Month               16809 non-null  float64
#  8   Stress_Level        16809 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.3+ MB
# None

# %%
df.columns
# Out:
# Index(['Student_Type', 'Sleep_Hours', 'Study_Hours', 'Social_Media_Hours',
#        'Attendance', 'Exam_Pressure', 'Family_Support', 'Month',
#        'Stress_Level'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16809 entries, 1 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        16809 non-null  object
#  1   Sleep_Hours         16809 non-null  float64
#  2   Study_Hours         16809 non-null  float64
#  3   Social_Media_Hours  16809 non-null  float64
#  4   Attendance          16809 non-null  float64
#  5   Exam_Pressure       16809 non-null  float64
#  6   Family_Support      16809 non-null  float64
#  7   Month               16809 non-null  float64
#  8   Stress_Level        16809 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
# Plotting only useful columns
grid = sns.pairplot(df,corner=True)

# %%
# For saving the plot
'''


grid.savefig('stress.png', dpi=300, bbox_inches='tight')


'''
print('This plot gives us a rough idea of the data')
# Out:
# This plot gives us a rough idea of the data

# %%
plt.figure(figsize=(18,16))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Student_Type', 'Sleep_Hours', 'Study_Hours', 'Social_Media_Hours',
#        'Attendance', 'Exam_Pressure', 'Family_Support', 'Month',
#        'Stress_Level'],
#       dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Sleep_Hours', 'Study_Hours', 'Social_Media_Hours', 'Attendance',
#        'Exam_Pressure', 'Family_Support', 'Month', 'Stress_Level'],
#       dtype='object')

# %%
churnplot = sns.pairplot(
            df,
            vars=df.select_dtypes(include='number').columns,
            hue='Student_Type',
            plot_kws={'alpha':0.5},
            corner = True
            )

# %%
'''

churnplot.savefig('StressCat.png', dpi=300, bbox_inches='tight')

'''
# Out:
# "\n\nchurnplot.savefig('StressCat.png', dpi=300, bbox_inches='tight')\n\n"

# %%
# Boxplot for outlier detection

numerical_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(20, 16))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16809 entries, 1 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        16809 non-null  object
#  1   Sleep_Hours         16809 non-null  float64
#  2   Study_Hours         16809 non-null  float64
#  3   Social_Media_Hours  16809 non-null  float64
#  4   Attendance          16809 non-null  float64
#  5   Exam_Pressure       16809 non-null  float64
#  6   Family_Support      16809 non-null  float64
#  7   Month               16809 non-null  float64
#  8   Stress_Level        16809 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
# Checking stats of every category
# 1 is good , 2 is average , 3 is bad

a = 'Student_Type'


adf = df[df[a] == "college"]
adf.describe()
# Out:
#        Sleep_Hours  Study_Hours  Social_Media_Hours   Attendance  \
# count  9259.000000  9259.000000         9259.000000  9259.000000
# mean      6.280811     4.985222            3.568684    81.232541
# std       1.478601     2.138819            1.902706    11.990342
# min       2.020814    -1.433434            0.000597    -5.000000
# 25%       5.275859     3.561186            2.162021    73.778541
# 50%       6.290615     4.943645            3.514874    81.869305
# 75%       7.289626     6.326900            4.883574    89.892149
# max       9.982310    19.738097            9.956754   120.000000
#
#        Exam_Pressure  Family_Support        Month  Stress_Level
# count    9259.000000     9259.000000  9259.000000   9259.000000
# mean        5.348310        5.829031     6.509018      0.312453
# std         2.393547        2.211597     3.460295      0.463518
# min         1.000000        1.000000     1.000000      0.000000
# ...

# %%
bdf = df[df[a] == "school"]
bdf.describe()
# Out:
#        Sleep_Hours  Study_Hours  Social_Media_Hours   Attendance  \
# count  4209.000000  4209.000000         4209.000000  4209.000000
# mean      7.420660     3.028846            3.536708    81.434280
# std       1.016329     1.354045            1.905692    11.739695
# min       3.753836    -1.188134            0.006803    -5.000000
# 25%       6.735541     2.112318            2.134472    73.983320
# 50%       7.423105     2.999402            3.452793    81.980847
# 75%       8.119211     3.907858            4.881544    90.316387
# max       9.979240    12.428364            9.962134   120.000000
#
#        Exam_Pressure  Family_Support        Month  Stress_Level
# count    4209.000000     4209.000000  4209.000000   4209.000000
# mean        5.370634        5.804704     6.510097      0.205987
# std         2.404537        2.250764     3.468483      0.404469
# min         1.000000        1.000000     1.000000      0.000000
# ...

# %%
cdf = df[df[a] == "working_student"]
cdf.describe()
# Out:
#        Sleep_Hours  Study_Hours  Social_Media_Hours   Attendance  \
# count  3341.000000  3341.000000         3341.000000  3341.000000
# mean      5.704818     6.088611            3.507703    81.290532
# std       1.485143     2.175588            1.867318    12.273188
# min       2.027362    -0.044755            0.002124    -5.000000
# 25%       4.691816     4.630613            2.148401    74.024504
# 50%       5.680624     6.052071            3.450446    82.133441
# 75%       6.688625     7.524794            4.774071    89.954656
# max       9.900778    21.979263            9.403828   120.000000
#
#        Exam_Pressure  Family_Support        Month  Stress_Level
# count    3341.000000     3341.000000  3341.000000   3341.000000
# mean        5.377432        5.794373     6.439389      0.378928
# std         2.410000        2.251529     3.448031      0.485193
# min         1.000000        1.000000     1.000000      0.000000
# ...

# %%
for i in df.select_dtypes(include=['object', 'string']):
    counts = df[i].value_counts()
    print(counts)
# Out:
# Student_Type
# college            9259
# school             4209
# working_student    3341
# Name: count, dtype: int64
